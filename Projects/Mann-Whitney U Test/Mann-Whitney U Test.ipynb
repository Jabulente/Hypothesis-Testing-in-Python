# %% [markdown]
# <h2 style='font-family: French Script MT; font-weight: 600; font-size: 30px; text-align: left'>1.0. Import Required Libraries</h2>

# %%
from scipy.stats import mannwhitneyu
from itertools import combinations
import pandas as pd  
import numpy as np 

import warnings  
warnings.simplefilter("ignore")  
pd.set_option('display.max_columns', 7) 
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# <h2 style='font-family: French Script MT; font-weight: 600; font-size: 30px; text-align: left'>2.0. Load and Inspect Dataset</h2>

# %%
filepath = "Datasets/Fertilizer and Light Exposure Experiment Dataset.csv"
df = pd.read_csv(filepath)
display(df)
# Out:
#     Fertilizer Light Exposure  Plant Height (cm)  ...  Flower Count (number)  \
# 0      Control       Full Sun              58.56  ...                  19.54
# 1      Organic     Full Shade              46.70  ...                  15.37
# 2      Control  Partial Shade              58.33  ...                  16.39
# 3      Control     Full Shade              42.73  ...                  12.45
# 4      Organic     Full Shade              41.82  ...                  15.14
# ..         ...            ...                ...  ...                    ...
# 115  Synthetic  Partial Shade              65.24  ...                  21.14
# 116    Organic  Partial Shade              63.56  ...                  16.11
# 117    Control  Partial Shade              62.75  ...                  17.99
# 118    Control     Full Shade              39.60  ...                  13.72
# 119  Synthetic     Full Shade              41.75  ...                  13.60
#
#      Seed Yield (g)  Stomatal Conductance (mmol/m²/s)
# 0              6.69                            242.41
# 1              6.17                            233.66
# 2              5.41                            230.07
# 3              4.26                            154.25
# 4              4.64                            200.54
# ..              ...                               ...
# 115            7.48                            254.78
# 116            6.17                            234.22
# 117            6.18                            278.97
# 118            4.46                            186.87
# 119            4.94                            180.23
#
# [120 rows x 10 columns]

# %% [markdown]
# <h2 style='font-family: French Script MT; font-weight: 600; font-size: 30px; text-align: left'>3.0. Mann-Whitney U Test</h2>

# %%
def mannwhitneyu_test(df, group_cols, variables):
    results = []
    for category in group_cols:
        unique_groups = df[category].unique()
        group_combinations = list(combinations(unique_groups, 2))
        
        for column in variables:
            for group1, group2 in group_combinations:
                group1_data = df[df[category] == group1][column].dropna()
                group2_data = df[df[category] == group2][column].dropna()
                
                if len(group1_data) > 1 and len(group2_data) > 1:
                    t_stat, p_value = mannwhitneyu(group1_data, group2_data, alternative='two-sided')
                    
                    results.append({
                        'Group': category,
                        'Variable': column,
                        'Group 1': group1,
                        'Group 2': group2,
                        'Mean Diff.': group1_data.mean() - group2_data.mean(),
                        'U-Statistic': t_stat,
                        'P-Value': p_value,
                        'Significant (α=0.05)': 'Significant' if p_value < 0.05 else 'Not Significant'
                    })
    
    return pd.DataFrame(results)


group_cols = ['Fertilizer', 'Light Exposure']
variables = ['Plant Height (cm)', 'Leaf Area (cm²)', 'Chlorophyll Content (SPAD units)']
results = mannwhitneyu_test(df, group_cols=group_cols, variables=variables)

pd.set_option('display.float_format', '{:.4f}'.format)
display(results.style.format({
    'Mean Diff.': '{:.2f}',
    'U-Statistic': '{:.3f}',
    'P-Value': '{:.4f}'
}).background_gradient(subset=['P-Value'], cmap='YlOrRd'))
# Out:
# <style type="text/css">
# #T_4a4df_row0_col6 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_4a4df_row1_col6 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_4a4df_row2_col6 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# #T_4a4df_row3_col6 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_4a4df_row4_col6 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_4a4df_row5_col6 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_4a4df_row6_col6 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_4a4df_row7_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_4a4df_row8_col6 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_4a4df_row9_col6, #T_4a4df_row10_col6, #T_4a4df_row11_col6, #T_4a4df_row12_col6, #T_4a4df_row13_col6, #T_4a4df_row14_col6, #T_4a4df_row15_col6, #T_4a4df_row16_col6, #T_4a4df_row17_col6 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_4a4df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a4df_level0_col0" class="col_heading level0 col0" >Group</th>
#       <th id="T_4a4df_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_4a4df_level0_col2" class="col_heading level0 col2" >Group 1</th>
#       <th id="T_4a4df_level0_col3" class="col_heading level0 col3" >Group 2</th>
#       <th id="T_4a4df_level0_col4" class="col_heading level0 col4" >Mean Diff.</th>
#       <th id="T_4a4df_level0_col5" class="col_heading level0 col5" >U-Statistic</th>
#       <th id="T_4a4df_level0_col6" class="col_heading level0 col6" >P-Value</th>
#       <th id="T_4a4df_level0_col7" class="col_heading level0 col7" >Significant (α=0.05)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a4df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a4df_row0_col0" class="data row0 col0" >Fertilizer</td>
#       <td id="T_4a4df_row0_col1" class="data row0 col1" >Plant Height (cm)</td>
#       <td id="T_4a4df_row0_col2" class="data row0 col2" >Control</td>
#       <td id="T_4a4df_row0_col3" class="data row0 col3" >Organic</td>
#       <td id="T_4a4df_row0_col4" class="data row0 col4" >-11.06</td>
#       <td id="T_4a4df_row0_col5" class="data row0 col5" >510.000</td>
#       <td id="T_4a4df_row0_col6" class="data row0 col6" >0.0054</td>
#       <td id="T_4a4df_row0_col7" class="data row0 col7" >Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a4df_row1_col0" class="data row1 col0" >Fertilizer</td>
#       <td id="T_4a4df_row1_col1" class="data row1 col1" >Plant Height (cm)</td>
#       <td id="T_4a4df_row1_col2" class="data row1 col2" >Control</td>
#       <td id="T_4a4df_row1_col3" class="data row1 col3" >Synthetic</td>
#       <td id="T_4a4df_row1_col4" class="data row1 col4" >-7.28</td>
#       <td id="T_4a4df_row1_col5" class="data row1 col5" >549.000</td>
#       <td id="T_4a4df_row1_col6" class="data row1 col6" >0.0106</td>
#       <td id="T_4a4df_row1_col7" class="data row1 col7" >Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a4df_row2_col0" class="data row2 col0" >Fertilizer</td>
#       <td id="T_4a4df_row2_col1" class="data row2 col1" >Plant Height (cm)</td>
#       <td id="T_4a4df_row2_col2" class="data row2 col2" >Organic</td>
#       <td id="T_4a4df_row2_col3" class="data row2 col3" >Synthetic</td>
#       <td id="T_4a4df_row2_col4" class="data row2 col4" >3.78</td>
#       <td id="T_4a4df_row2_col5" class="data row2 col5" >877.000</td>
#       <td id="T_4a4df_row2_col6" class="data row2 col6" >0.3440</td>
#       <td id="T_4a4df_row2_col7" class="data row2 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a4df_row3_col0" class="data row3 col0" >Fertilizer</td>
#       <td id="T_4a4df_row3_col1" class="data row3 col1" >Leaf Area (cm²)</td>
#       <td id="T_4a4df_row3_col2" class="data row3 col2" >Control</td>
#       <td id="T_4a4df_row3_col3" class="data row3 col3" >Organic</td>
#       <td id="T_4a4df_row3_col4" class="data row3 col4" >-26.50</td>
#       <td id="T_4a4df_row3_col5" class="data row3 col5" >618.000</td>
#       <td id="T_4a4df_row3_col6" class="data row3 col6" >0.0815</td>
#       <td id="T_4a4df_row3_col7" class="data row3 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a4df_row4_col0" class="data row4 col0" >Fertilizer</td>
#       <td id="T_4a4df_row4_col1" class="data row4 col1" >Leaf Area (cm²)</td>
#       <td id="T_4a4df_row4_col2" class="data row4 col2" >Control</td>
#       <td id="T_4a4df_row4_col3" class="data row4 col3" >Synthetic</td>
#       <td id="T_4a4df_row4_col4" class="data row4 col4" >-16.60</td>
#       <td id="T_4a4df_row4_col5" class="data row4 col5" >644.000</td>
#       <td id="T_4a4df_row4_col6" class="data row4 col6" >0.0974</td>
#       <td id="T_4a4df_row4_col7" class="data row4 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a4df_row5_col0" class="data row5 col0" >Fertilizer</td>
#       <td id="T_4a4df_row5_col1" class="data row5 col1" >Leaf Area (cm²)</td>
#       <td id="T_4a4df_row5_col2" class="data row5 col2" >Organic</td>
#       <td id="T_4a4df_row5_col3" class="data row5 col3" >Synthetic</td>
#       <td id="T_4a4df_row5_col4" class="data row5 col4" >9.89</td>
#       <td id="T_4a4df_row5_col5" class="data row5 col5" >861.000</td>
#       <td id="T_4a4df_row5_col6" class="data row5 col6" >0.4299</td>
#       <td id="T_4a4df_row5_col7" class="data row5 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a4df_row6_col0" class="data row6 col0" >Fertilizer</td>
#       <td id="T_4a4df_row6_col1" class="data row6 col1" >Chlorophyll Content (SPAD units)</td>
#       <td id="T_4a4df_row6_col2" class="data row6 col2" >Control</td>
#       <td id="T_4a4df_row6_col3" class="data row6 col3" >Organic</td>
#       <td id="T_4a4df_row6_col4" class="data row6 col4" >-5.09</td>
#       <td id="T_4a4df_row6_col5" class="data row6 col5" >605.000</td>
#       <td id="T_4a4df_row6_col6" class="data row6 col6" >0.0619</td>
#       <td id="T_4a4df_row6_col7" class="data row6 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a4df_row7_col0" class="data row7 col0" >Fertilizer</td>
#       <td id="T_4a4df_row7_col1" class="data row7 col1" >Chlorophyll Content (SPAD units)</td>
#       <td id="T_4a4df_row7_col2" class="data row7 col2" >Control</td>
#       <td id="T_4a4df_row7_col3" class="data row7 col3" >Synthetic</td>
#       <td id="T_4a4df_row7_col4" class="data row7 col4" >-1.84</td>
#       <td id="T_4a4df_row7_col5" class="data row7 col5" >747.000</td>
#       <td id="T_4a4df_row7_col6" class="data row7 col6" >0.4934</td>
#       <td id="T_4a4df_row7_col7" class="data row7 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a4df_row8_col0" class="data row8 col0" >Fertilizer</td>
#       <td id="T_4a4df_row8_col1" class="data row8 col1" >Chlorophyll Content (SPAD units)</td>
#       <td id="T_4a4df_row8_col2" class="data row8 col2" >Organic</td>
#       <td id="T_4a4df_row8_col3" class="data row8 col3" >Synthetic</td>
#       <td id="T_4a4df_row8_col4" class="data row8 col4" >3.26</td>
#       <td id="T_4a4df_row8_col5" class="data row8 col5" >904.000</td>
#       <td id="T_4a4df_row8_col6" class="data row8 col6" >0.2259</td>
#       <td id="T_4a4df_row8_col7" class="data row8 col7" >Not Significant</td>
#     </tr>
#     <tr>
#       <th id="T_4a4df_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a4df_row9_col0" class="data row9 col0" >Light Exposure</td>
#       <td id="T_4a4df_row9_col1" class="data row9 col1" >Plant He

# %% [markdown]
# ---
#
# This analysis was performed by **Jabulente**, a passionate and dedicated data analyst with a strong commitment to using data to drive meaningful insights and solutions. For inquiries, collaborations, or further discussions, please feel free to reach out via.
#
# ----
#
# <div align="center">
#
# [![GitHub](https://img.shields.io/badge/GitHub-Jabulente-black?logo=github)](https://github.com/Jabulente)  [![LinkedIn](https://img.shields.io/badge/LinkedIn-Jabulente-blue?logo=linkedin)](https://linkedin.com/in/jabulente-208019349)  [![Email](https://img.shields.io/badge/Email-jabulente@hotmail.com-red?logo=gmail)](mailto:Jabulente@hotmail.com)
#
# </div>

# %% [markdown]
# <h1 style='font-size: 35px; color: red; font-family: French Script MT; font-weight: 700; text-align: center'>Data to Drive Meaningful Insights and Solutions</h1>
