# %%
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import numpy as np
import re

def rename(text): return re.sub(r'[^a-zA-Z]', "", text)

def compute_two_way_anova(df, numerical_columns, group1, group2):
    results = []
    df = df.rename(columns={col: rename(col) for col in df.columns})
    
    for col in numerical_columns:
        var = rename(col)  
        group1_cleaned = rename(group1)
        group2_cleaned = rename(group2)
        formula = f"{var} ~  C({group1_cleaned}) * C({group2_cleaned})" 
        model = smf.ols(formula, data=df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        
        for source, row in anova_table.iterrows():
            p_value = row["PR(>F)"]
            interpretation = "Significant" if p_value < 0.05 else "No significant"
            if source == "Residual": interpretation = "-"
            
            results.append({
                #"Group": original_group,
                "Variable": col,
                "Source": source,
                "Sum Sq": row["sum_sq"],
                "df": row["df"],
                "F-Value": row["F"],
                "p-Value": p_value,
                "Significant (α<0.05)": interpretation
            })
    results = pd.DataFrame(results)
    return results

#if __name__ == "__main__":
df = pd.read_csv("../Datasets/Eggplant Fusarium Fertilizer Data.csv")
group1 = 'Fertilizer'
group2 = 'Variety'
variables = df.select_dtypes(include=[np.number]).columns  
anova_results = compute_two_way_anova(df, variables, group1, group2)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
display(anova_results)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
#                   Variable                    Source      Sum Sq       df  \
# 0           Replication ID             C(Fertilizer)         NaN   2.0000
# 1           Replication ID                C(Variety)         NaN   7.0000
# 2           Replication ID  C(Fertilizer):C(Variety)  37018.3653  14.0000
# 3           Replication ID                  Residual 670201.5198 792.0000
# 4   Infection Severity (%)             C(Fertilizer)         NaN   2.0000
# 5   Infection Severity (%)                C(Variety)         NaN   7.0000
# 6   Infection Severity (%)  C(Fertilizer):C(Variety)    386.0725  14.0000
# 7   Infection Severity (%)                  Residual  54593.4803 792.0000
# 8               Wilt index             C(Fertilizer)         NaN   2.0000
# 9               Wilt index                C(Variety)         NaN   7.0000
# 10              Wilt index  C(Fertilizer):C(Variety)      9.2101  14.0000
# 11              Wilt index                  Residual    266.2446 792.0000
# 12       Plant height (cm)             C(Fertilizer)         NaN   2.0000
# 13       Plant height (cm)                C(Variety)         NaN   7.0000
# 14       Plant height (cm)  C(Fertilizer):C(Variety)      0.2557  14.0000
# 15       Plant height (cm)                  Residual  24356.3698 792.0000
# 16   Days to wilt symptoms             C(Fertilizer)         NaN   2.0000
# 17   Days to wilt symptoms                C(Variety)         NaN   7.0000
# 18   Days to wilt symptoms  C(Fertilizer):C(Variety)      0.4924  14.0000
# 19   Days to wilt symptoms                  Residual   2012.3087 792.0000
# 20       Survival rate (%)             C(Fertilizer)         NaN   2.0000
# 21       Survival rate (%)                C(Variety)         NaN   7.0000
# 22       Survival rate (%)  C(Fertilizer):C(Variety)     47.4854  14.0000
# 23       Survival rate (%)                  Residual  48706.2064 792.0000
# 24   Disease incidence (%)             C(Fertilizer)         NaN   2.0000
# 25   Disease incidence (%)                C(Variety)         NaN   7.0000
# 26   Disease incidence (%)  C(Fertilizer):C(Variety)    732.4972  14.0000
# 27   Disease incidence (%)                  Residual  45815.5180 792.0000
#
#     F-Value  p-Value Significant (α<0.05)
# 0       NaN      NaN       No significant
# 1       NaN      NaN       No significant
# 2    3.1247   0.0775       No significant
# 3       NaN      NaN                    -
# 4       NaN      NaN       No significant
# 5       NaN      NaN       No significant
# 6    0.4001   0.5272       No significant
# 7       NaN      NaN                    -
# 8       NaN      NaN       No significant
# 9       NaN      NaN       No significant
# 10   1.9570   0.1622       No significant
# 11      NaN      NaN                    -
# 12      NaN      NaN       No significant
# 13      NaN      NaN       No significant
# 14   0.0006   0.9806       No significant
# 15      NaN      NaN                    -
# 16      NaN      NaN       No significant
# 17      NaN      NaN       No significant
# 18   0.0138   0.9064       No significant
# 19      NaN      NaN                    -
# 20      NaN      NaN       No significant
# 21      NaN      NaN       No significant
# 22   0.0552   0.8144       No significant
# 23      NaN      NaN                    -
# 24      NaN      NaN       No significant
# 25      NaN      NaN       No significant
# 26   0.9045   0.3419       No significant
# 27      NaN      NaN                    -

# %%
df = pd.read_csv("../Datasets/Eggplant Fusarium Fertilizer Data.csv")
df
# Out:
#     Variety Fertilizer  Replication ID  Infection Severity (%)  Wilt index  \
# 0     EP-R1  Inorganic               1                 22.5000      0.7000
# 1     EP-R1  Inorganic               2                 27.9000      1.2000
# 2     EP-R1  Inorganic               3                 21.2000      0.0000
# 3     EP-R1  Inorganic               4                 15.5000      0.1000
# 4     EP-R1  Inorganic               5                 17.3000      0.9000
# ..      ...        ...             ...                     ...         ...
# 795   EP-S3    Control              96                 75.2000      3.6000
# 796   EP-S3    Control              97                 74.8000      4.9000
# 797   EP-S3    Control              98                 58.1000      3.6000
# 798   EP-S3    Control              99                 54.1000      4.1000
# 799   EP-S3    Control             100                 73.5000      3.4000
#
#      Plant height (cm)  Days to wilt symptoms  Survival rate (%)  \
# 0              88.9000                     21            88.8000
# 1              82.2000                     19            87.7000
# 2              74.7000                     17            84.9000
# 3              93.8000                     18            90.3000
# 4              78.1000                     19            87.0000
# ..                 ...                    ...                ...
# 795            68.2000                      7             6.4000
# 796            59.5000                      4            27.2000
# 797            78.8000                      7            30.8000
# 798            63.7000                      7            24.1000
# 799            67.4000                      5             8.6000
#
#      Disease incidence (%)
# 0                  23.4000
# 1                  21.7000
# 2                  27.2000
# 3                  15.0000
# 4                  23.0000
# ..                     ...
# 795                85.5000
# 796                82.0000
# 797                75.4000
# 798                81.8000
# 799                85.2000
#
# [800 rows x 9 columns]
