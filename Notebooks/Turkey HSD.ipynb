# %% [markdown]
# <h1 style='font-size: 35px; color: crimson; font-family: Colonna MT; font-weight: 600; text-align: center'>Tukeys Honest Significant Difference (THSD)</h1>
#
# ---

# %%
# Import Required Libraries
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pandas as pd

# Performe Turkey THSD for one variable at a time
# variable = 'Infection Severity (%)'
# group_column = 'Variety'
# turkey = pairwise_tukeyhsd(endog=df[Variable], groups=df[group_column], alpha=0.05)
# print(turkey)

# Automate test over multiple variables and retur results in formated DataFrame
def compute_turkey_results(df, Metrics, group_column):
    results_data = []
    for metric in Metrics:
        turkey_results = pairwise_tukeyhsd(endog=df[metric], groups=df[group_column], alpha=0.05)
        results_table = turkey_results.summary()
        
        for i in range(1, len(results_table)):
            row = results_table.data[i]
            results_data.append({
                'Category': group_column,
                'Metric': metric,
                'Group1': row[0],
                'Group2': row[1],
                'Mean Difference': row[2],
                'P-Value': row[3],
                'Lower CI': row[4],
                'Upper CI': row[5],
                'Reject Null': row[6]
            })
        
        result_df = pd.DataFrame(results_data)
    return result_df

# %%
# Import Cleaned and Structured Dataset
filepath = "./Datasets/Eggplant Fusarium Fertilizer Data.csv"
df = pd.read_csv(filepath)
display(df)
# Out:
#     Variety Fertilizer  Replication ID  Infection Severity (%)  Wilt index  \
# 0     EP-R1  Inorganic               1                  22.500       0.700
# 1     EP-R1  Inorganic               2                  27.900       1.200
# 2     EP-R1  Inorganic               3                  21.200       0.000
# 3     EP-R1  Inorganic               4                  15.500       0.100
# 4     EP-R1  Inorganic               5                  17.300       0.900
# ..      ...        ...             ...                     ...         ...
# 795   EP-S3    Control              96                  75.200       3.600
# 796   EP-S3    Control              97                  74.800       4.900
# 797   EP-S3    Control              98                  58.100       3.600
# 798   EP-S3    Control              99                  54.100       4.100
# 799   EP-S3    Control             100                  73.500       3.400
#
#      Plant height (cm)  Days to wilt symptoms  Survival rate (%)  \
# 0               88.900                     21             88.800
# 1               82.200                     19             87.700
# 2               74.700                     17             84.900
# 3               93.800                     18             90.300
# 4               78.100                     19             87.000
# ..                 ...                    ...                ...
# 795             68.200                      7              6.400
# 796             59.500                      4             27.200
# 797             78.800                      7             30.800
# 798             63.700                      7             24.100
# 799             67.400                      5              8.600
#
#      Disease incidence (%)
# 0                   23.400
# 1                   21.700
# 2                   27.200
# 3                   15.000
# 4                   23.000
# ..                     ...
# 795                 85.500
# 796                 82.000
# 797                 75.400
# 798                 81.800
# 799                 85.200
#
# [800 rows x 9 columns]

# %%
# Performe Turkey THSD for one variable at a time
variable = 'Infection Severity (%)'
group_column = 'Variety'
turkey = pairwise_tukeyhsd(endog=df[variable], groups=df[group_column], alpha=0.05)
print(turkey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#  EP-M1  EP-M2     1.27 0.9603  -2.2944   4.8344  False
#  EP-M1  EP-R1  -23.478    0.0 -27.0424 -19.9136   True
#  EP-M1  EP-R2  -23.354    0.0 -26.9184 -19.7896   True
#  EP-M1  EP-R3  -23.273    0.0 -26.8374 -19.7086   True
#  EP-M1  EP-S1   31.092    0.0  27.5276  34.6564   True
#  EP-M1  EP-S2   29.821    0.0  26.2566  33.3854   True
#  EP-M1  EP-S3   29.742    0.0  26.1776  33.3064   True
#  EP-M2  EP-R1  -24.748    0.0 -28.3124 -21.1836   True
#  EP-M2  EP-R2  -24.624    0.0 -28.1884 -21.0596   True
#  EP-M2  EP-R3  -24.543    0.0 -28.1074 -20.9786   True
#  EP-M2  EP-S1   29.822    0.0  26.2576  33.3864   True
#  EP-M2  EP-S2   28.551    0.0  24.9866  32.1154   True
#  EP-M2  EP-S3   28.472    0.0  24.9076  32.0364   True
#  EP-R1  EP-R2    0.124    1.0  -3.4404   3.6884  False
#  EP-R1  EP-R3    0.205    1.0  -3.3594   3.7694  False
#  EP-R1  EP-S1    54.57    0.0  51.0056  58.1344   True
#  EP-R1  EP-S2   53.299    0.0  49.7346  56.8634   True
#  EP-R1  EP-S3    53.22    0.0  49.6556  56.7844   True
#  EP-R2  EP-R3    0.081    1.0  -3.4834   3.6454  False
#  EP-R2  EP-S1   54.446    0.0  50.8816  58.0104   True
#  EP-R2  EP-S2   53.175    0.0  49.6106  56.7394   True
#  EP-R2  EP-S3   53.096    0.0  49.5316  56.6604   True
#  EP-R3  EP-S1   54.365    0.0  50.8006  57.9294   True
#  EP-R3  EP-S2   53.094    0.0  49.5296  56.6584   True
#  EP-R3  EP-S3   53.015    0.0  49.4506  56.5794   True
#  EP-S1  EP-S2   -1.271 0.9602  -4.8354   2.2934  False
#  EP-S1  EP-S3    -1.35 0.9451  -4.9144   2.2144  False
#  EP-S2  EP-S3   -0.079    1.0  -3.6434   3.4854  False
# ------------------------------------------------------

# %%
# Main execution
if __name__ == "__main__":
    # Load data
    DATA_PATH = "./Datasets/Eggplant Fusarium Fertilizer Data.csv"
    df = pd.read_csv(DATA_PATH)
    
    # Define metrics to analyze
    ANALYSIS_METRICS = [
        'Infection Severity (%)',
        'Wilt index', 
        'Plant height (cm)', 
        'Days to wilt symptoms', 
        'Survival rate (%)', 
        'Disease incidence (%)'
    ]
    
    # Perform analysis
    tukey_results = compute_turkey_results(df, ANALYSIS_METRICS, group_column='Variety')
    
    # Configure display options
    pd.set_option("display.float_format", "{:.3f}".format)
    
    # Show first 10 results
    display(tukey_results.head(10))
# Out:
#   Category                  Metric Group1 Group2  Mean Difference  P-Value  \
# 0  Variety  Infection Severity (%)  EP-M1  EP-M2            1.270    0.960
# 1  Variety  Infection Severity (%)  EP-M1  EP-R1          -23.478    0.000
# 2  Variety  Infection Severity (%)  EP-M1  EP-R2          -23.354    0.000
# 3  Variety  Infection Severity (%)  EP-M1  EP-R3          -23.273    0.000
# 4  Variety  Infection Severity (%)  EP-M1  EP-S1           31.092    0.000
# 5  Variety  Infection Severity (%)  EP-M1  EP-S2           29.821    0.000
# 6  Variety  Infection Severity (%)  EP-M1  EP-S3           29.742    0.000
# 7  Variety  Infection Severity (%)  EP-M2  EP-R1          -24.748    0.000
# 8  Variety  Infection Severity (%)  EP-M2  EP-R2          -24.624    0.000
# 9  Variety  Infection Severity (%)  EP-M2  EP-R3          -24.543    0.000
#
#    Lower CI  Upper CI  Reject Null
# 0    -2.294     4.834        False
# 1   -27.042   -19.914         True
# 2   -26.918   -19.790         True
# 3   -26.837   -19.709         True
# 4    27.528    34.656         True
# 5    26.257    33.385         True
# 6    26.178    33.306         True
# 7   -28.312   -21.184         True
# 8   -28.188   -21.060         True
# 9   -28.107   -20.979         True
